# %%
import numpy as np
import pandas as pd

# %%
match = pd.read_csv('./datas/matches.csv')
delivery = pd.read_csv('./datas/deliveries.csv')

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
match.shape
# Out:
# (1095, 20)

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
delivery.shape
# Out:
# (260920, 17)

# %%
total_score_df = delivery.groupby(['match_id', 'inning']).sum()['total_runs'].reset_index()

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 1       335982       2          82
# 2       335983       1         240
# 3       335983       2         207
# 4       335984       1         129
# ...        ...     ...         ...
# 2212   1426310       2         174
# 2213   1426311       1         175
# 2214   1426311       2         139
# 2215   1426312       1         113
# 2216   1426312       2         114
#
# [2217 rows x 3 columns]

# %%
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
total_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 2       335983       1         240
# 4       335984       1         129
# 6       335985       1         165
# 8       335986       1         110
# ...        ...     ...         ...
# 2207   1426307       1         214
# 2209   1426309       1         159
# 2211   1426310       1         172
# 2213   1426311       1         175
# 2215   1426312       1         113
#
# [1095 rows x 3 columns]

# %%
match_df = match.merge(total_score_df[['match_id', 'total_runs']], left_on='id', right_on='match_id')

# %%
match_df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...                                                 ...
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                        team2  \
# 0     Royal Challengers Bangalore        Kolkata Knight Riders
# 1                 Kings XI Punjab          Chennai Super Kings
# 2                Delhi Daredevils             Rajasthan Royals
# 3                  Mumbai Indians  Royal Challengers Bangalore
# 4           Kolkata Knight Riders              Deccan Chargers
# ...                           ...                          ...
# 1090                 Punjab Kings          Sunrisers Hyderabad
# 1091          Sunrisers Hyderabad        Kolkata Knight Riders
# 1092  Royal Challengers Bengaluru             Rajasthan Royals
# 1093          Sunrisers Hyderabad             Rajasthan Royals
# 1094          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                       toss_winner  ...   result result_margin target_runs  \
# 0     Royal Challengers Bangalore  ...     runs         140.0       223.0
# 1             Chennai Super Kings  ...     runs          33.0       241.0
# 2                Rajasthan Royals  ...  wickets           9.0       130.0
# 3                  Mumbai Indians  ...  wickets           5.0       166.0
# 4                 Deccan Chargers  ...  wickets           5.0       111.0
# ...                           ...  ...      ...           ...         ...
# 1090                 Punjab Kings  ...  wickets           4.0       215.0
# 1091          Sunrisers Hyderabad  ...  wickets           8.0       160.0
# 1092             Rajasthan Royals  ...  wickets           4.0       173.0
# 1093             Rajasthan Royals  ...     runs          36.0       176.0
# 1094          Sunrisers Hyderabad  ...  wickets           8.0       114.0
#
#       target_overs  super_over  method                umpire1  \
# 0             20.0           N     NaN              Asad Rauf
# 1             20.0           N     NaN              MR Benson
# 2             20.0           N     NaN              Aleem Dar
# 3             20.0           N     NaN               SJ Davis
# 4             20.0           N     NaN              BF Bowden
# ...            ...         ...     ...                    ...
# 1090          20.0           N     NaN            Nitin Menon
# 1091          20.0           N     NaN           AK Chaudhary
# 1092          20.0           N     NaN  KN Ananthapadmanabhan
# 1093          20.0           N     NaN            Nitin Menon
# 1094          20.0           N     NaN          J Madanagopal
#
#                    umpire2 match_id total_runs
# 0              RE Koertzen   335982        222
# 1               SL Shastri   335983        240
# 2           GA Pratapkumar   335984        129
# 3                DJ Harper   335985        165
# 4              K Hariharan   335986        110
# ...                    ...      ...        ...
# 1090             VK Sharma  1426307        214
# 1091              R Pandit  1426309        159
# 1092  MV Saidharshan Kumar  1426310        172
# 1093             VK Sharma  1426311        175
# 1094           Nitin Menon  1426312        113
#
# [1095 rows x 22 columns]

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams= [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bengaluru',
    'Kolkata Knight Riders',
    'Punjab Kings',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
team_mapping = {
    'Delhi Daredevils': 'Delhi Capitals',
    'Kings XI Punjab': 'Punjab Kings',
    'Royal Challengers Bangalore': 'Royal Challengers Bengaluru',
    'Rising Pune Supergiant': 'Rising Pune Supergiants'
}

match_df.replace(team_mapping, inplace=True)

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (826, 22)

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Rajasthan Royals', 'Chennai Super Kings',
#        'Kolkata Knight Riders', 'Sunrisers Hyderabad'], dtype=object)

# %%
match_df = match_df[['match_id', 'city', 'winner', 'total_runs']]

# %%
delivery_df = match_df.merge(delivery, on='match_id')

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 0         335982  Bangalore  Kolkata Knight Riders           222       1
# 1         335982  Bangalore  Kolkata Knight Riders           222       1
# 2         335982  Bangalore  Kolkata Knight Riders           222       1
# 3         335982  Bangalore  Kolkata Knight Riders           222       1
# 4         335982  Bangalore  Kolkata Knight Riders           222       1
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                  batting_team                 bowling_team  over  ball  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1       Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2       Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3       Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 4       Kolkata Knight Riders  Royal Challengers Bangalore     0     5
# ...                       ...                          ...   ...   ...
# 196792  Kolkata Knight Riders          Sunrisers Hyderabad     9     5
# 196793  Kolkata Knight Riders          Sunrisers Hyderabad     9     6
# 196794  Kolkata Knight Riders          Sunrisers Hyderabad    10     1
# 196795  Kolkata Knight Riders          Sunrisers Hyderabad    10     2
# 196796  Kolkata Knight Riders          Sunrisers Hyderabad    10     3
#
#              batter         bowler  non_striker  batsman_runs  extra_runs  \
# 0        SC Ganguly        P Kumar  BB McCullum             0           1
# 1       BB McCullum        P Kumar   SC Ganguly             0           0
# 2       BB McCullum        P Kumar   SC Ganguly             0           1
# 3       BB McCullum        P Kumar   SC Ganguly             0           0
# 4       BB McCullum        P Kumar   SC Ganguly             0           0
# ...             ...            ...          ...           ...         ...
# 196792      SS Iyer     AK Markram      VR Iyer             1           0
# 196793      VR Iyer     AK Markram      SS Iyer             1           0
# 196794      VR Iyer  Shahbaz Ahmed      SS Iyer             1           0
# 196795      SS Iyer  Shahbaz Ahmed      VR Iyer             1           0
# 196796      VR Iyer  Shahbaz Ahmed      SS Iyer             1           0
#
#         total_runs_y extras_type  is_wicket player_dismissed dismissal_kind  \
# 0                  1     legbyes          0              NaN            NaN
# 1                  0         NaN          0              NaN            NaN
# 2                  1       wides          0              NaN            NaN
# 3                  0         NaN          0              NaN            NaN
# 4                  0         NaN          0              NaN            NaN
# ...              ...         ...        ...              ...            ...
# 196792             1         NaN          0              NaN            NaN
# 196793             1         NaN          0              NaN            NaN
# 196794             1         NaN          0              NaN            NaN
# 196795             1         NaN          0              NaN            NaN
# 196796             1         NaN          0              NaN            NaN
#
#        fielder
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 196792     NaN
# 196793     NaN
# 196794     NaN
# 196795     NaN
# 196796     NaN
#
# [196797 rows x 20 columns]

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter         bowler non_striker  batsman_runs  extra_runs  \
# 124     R Dravid       AB Dinda    W Jaffer             1           0
# 125     W Jaffer       AB Dinda    R Dravid             0           1
# 126     W Jaffer       AB Dinda    R Dravid             0           0
# 127     W Jaffer       AB Dinda    R Dravid             1           0
# 128     R Dravid       AB Dinda    W Jaffer             1           0
# ...          ...            ...         ...           ...         ...
# 196792   SS Iyer     AK Markram     VR Iyer             1           0
# 196793   VR Iyer     AK Markram     SS Iyer             1           0
# 196794   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 196795   SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 196796   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
#         total_runs_y extras_type  is_wicket player_dismissed dismissal_kind  \
# 124                1         NaN          0              NaN            NaN
# 125                1       wides          0              NaN            NaN
# 126                0         NaN          0              NaN            NaN
# 127                1         NaN          0              NaN            NaN
# 128                1         NaN          0              NaN            NaN
# ...              ...         ...        ...              ...            ...
# 196792             1         NaN          0              NaN            NaN
# 196793             1         NaN          0              NaN            NaN
# 196794             1         NaN          0              NaN            NaN
# 196795             1         NaN          0              NaN            NaN
# 196796             1         NaN          0              NaN            NaN
#
#        fielder
# 124        NaN
# 125        NaN
# 126        NaN
# 127        NaN
# 128        NaN
# ...        ...
# 196792     NaN
# 196793     NaN
# 196794     NaN
# 196795     NaN
# 196796     NaN
#
# [94803 rows x 20 columns]

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_16888\1894988650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... non_striker batsman_runs  extra_runs  total_runs_y  \
# 124     R Dravid  ...    W Jaffer            1           0             1
# 125     W Jaffer  ...    R Dravid            0           1             1
# 126     W Jaffer  ...    R Dravid            0           0             0
# 127     W Jaffer  ...    R Dravid            1           0             1
# 128     R Dravid  ...    W Jaffer            1           0             1
# ...          ...  ...         ...          ...         ...           ...
# 196792   SS Iyer  ...     VR Iyer            1           0             1
# 196793   VR Iyer  ...     SS Iyer            1           0             1
# 196794   VR Iyer  ...     SS Iyer            1           0             1
# 196795   SS Iyer  ...     VR Iyer            1           0             1
# 196796   VR Iyer  ...     SS Iyer            1           0             1
#
#         extras_type is_wicket  player_dismissed dismissal_kind fielder  \
# 124             NaN         0               NaN            NaN     NaN
# 125           wides         0               NaN            NaN     NaN
# 126             NaN         0               NaN            NaN     NaN
# 127             NaN         0               NaN            NaN     NaN
# 128             NaN         0               NaN            NaN     NaN
# ...             ...       ...               ...            ...     ...
# 196792          NaN         0               NaN            NaN     NaN
# 196793          NaN         0               NaN            NaN     NaN
# 196794          NaN         0               NaN            NaN     NaN
# 196795          NaN         0               NaN            NaN     NaN
# 196796          NaN         0               NaN            NaN     NaN
#
#        current_score
# 124                1
# 125                2
# 126                2
# 127                3
# 128                4
# ...              ...
# 196792           110
# 196793           111
# 196794           112
# 196795           113
# 196796           114
#
# [94803 rows x 21 columns]

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_16888\1162889266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... batsman_runs extra_runs  total_runs_y  extras_type  \
# 124     R Dravid  ...            1          0             1          NaN
# 125     W Jaffer  ...            0          1             1        wides
# 126     W Jaffer  ...            0          0             0          NaN
# 127     W Jaffer  ...            1          0             1          NaN
# 128     R Dravid  ...            1          0             1          NaN
# ...          ...  ...          ...        ...           ...          ...
# 196792   SS Iyer  ...            1          0             1          NaN
# 196793   VR Iyer  ...            1          0             1          NaN
# 196794   VR Iyer  ...            1          0             1          NaN
# 196795   SS Iyer  ...            1          0             1          NaN
# 196796   VR Iyer  ...            1          0             1          NaN
#
#         is_wicket player_dismissed  dismissal_kind fielder current_score  \
# 124             0              NaN             NaN     NaN             1
# 125             0              NaN             NaN     NaN             2
# 126             0              NaN             NaN     NaN             2
# 127             0              NaN             NaN     NaN             3
# 128             0              NaN             NaN     NaN             4
# ...           ...              ...             ...     ...           ...
# 196792          0              NaN             NaN     NaN           110
# 196793          0              NaN             NaN     NaN           111
# 196794          0              NaN             NaN     NaN           112
# 196795          0              NaN             NaN     NaN           113
# 196796          0              NaN             NaN     NaN           114
#
#        runs_left
# 124          221
# 125          220
# 126          220
# 127          219
# 128          218
# ...          ...
# 196792         3
# 196793         2
# 196794         1
# 196795         0
# 196796        -1
#
# [94803 rows x 22 columns]

# %%
delivery_df['balls_left'] = 120 - (delivery_df['over']*6 + delivery_df['ball'])
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_16888\4247168279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left'] = 120 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... extra_runs total_runs_y  extras_type  is_wicket  \
# 124     R Dravid  ...          0            1          NaN          0
# 125     W Jaffer  ...          1            1        wides          0
# 126     W Jaffer  ...          0            0          NaN          0
# 127     W Jaffer  ...          0            1          NaN          0
# 128     R Dravid  ...          0            1          NaN          0
# ...          ...  ...        ...          ...          ...        ...
# 196792   SS Iyer  ...          0            1          NaN          0
# 196793   VR Iyer  ...          0            1          NaN          0
# 196794   VR Iyer  ...          0            1          NaN          0
# 196795   SS Iyer  ...          0            1          NaN          0
# 196796   VR Iyer  ...          0            1          NaN          0
#
#         player_dismissed dismissal_kind  fielder current_score runs_left  \
# 124                  NaN            NaN      NaN             1       221
# 125                  NaN            NaN      NaN             2       220
# 126                  NaN            NaN      NaN             2       220
# 127                  NaN            NaN      NaN             3       219
# 128                  NaN            NaN      NaN             4       218
# ...                  ...            ...      ...           ...       ...
# 196792               NaN            NaN      NaN           110         3
# 196793               NaN            NaN      NaN           111         2
# 196794               NaN            NaN      NaN           112         1
# 196795               NaN            NaN      NaN           113         0
# 196796               NaN            NaN      NaN           114        -1
#
#        balls_left
# 124           119
# 125           118
# 126           117
# 127           116
# 128           115
# ...           ...
# 196792         61
# 196793         60
# 196794         59
# 196795         58
# 196796         57
#
# [94803 rows x 23 columns]

# %%
wickets = delivery_df.groupby('match_id')['is_wicket'].cumsum()

delivery_df['wickets_left'] = 10 - wickets
delivery_df.head()
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_16888\551396677.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wickets_left'] = 10 - wickets
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders           222       2
# 125    335982  Bangalore  Kolkata Knight Riders           222       2
# 126    335982  Bangalore  Kolkata Knight Riders           222       2
# 127    335982  Bangalore  Kolkata Knight Riders           222       2
# 128    335982  Bangalore  Kolkata Knight Riders           222       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs_y extras_type  is_wicket  player_dismissed  \
# 124  ...            1         NaN          0               NaN
# 125  ...            1       wides          0               NaN
# 126  ...            0         NaN          0               NaN
# 127  ...            1         NaN          0               NaN
# 128  ...            1         NaN          0               NaN
#
#      dismissal_kind fielder  current_score runs_left balls_left wickets_left
# 124             NaN     NaN              1       221        119           10
# 125             NaN     NaN              2       220        118           10
# 126             NaN     NaN              2       220        117           10
# 127             NaN     NaN              3       219        116           10
# 128             NaN     NaN              4       218        115           10
#
# [5 rows x 24 columns]

# %%
delivery_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94803 entries, 124 to 196796
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          94803 non-null  int64
#  1   city              88791 non-null  object
#  2   winner            94776 non-null  object
#  3   total_runs_x      94803 non-null  int64
#  4   inning            94803 non-null  int64
#  5   batting_team      94803 non-null  object
#  6   bowling_team      94803 non-null  object
#  7   over              94803 non-null  int64
#  8   ball              94803 non-null  int64
#  9   batter            94803 non-null  object
#  10  bowler            94803 non-null  object
#  11  non_striker       94803 non-null  object
#  12  batsman_runs      94803 non-null  int64
#  13  extra_runs        94803 non-null  int64
#  14  total_runs_y      94803 non-null  int64
#  15  extras_type       5048 non-null   object
#  16  is_wicket         94803 non-null  int64
#  17  player_dismissed  4665 non-null   object
#  18  dismissal_kind    4665 non-null   object
#  19  fielder           3302 non-null   object
#  20  current_score     94803 non-null  int64
#  21  runs_left         94803 non-null  int64
#  22  balls_left        94803 non-null  int64
#  23  wickets_left      94803 non-null  int64
# dtypes: int64(13), object(11)
# memory usage: 18.1+ MB

# %%
# crr = current_runs / overs
delivery_df['crr'] = delivery_df['current_score'] / (delivery_df['over'] + (delivery_df['ball'] / 6.0))
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_16888\2303712052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['crr'] = delivery_df['current_score'] / (delivery_df['over'] + (delivery_df['ball'] / 6.0))

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... extras_type is_wicket  player_dismissed  dismissal_kind  \
# 124     R Dravid  ...         NaN         0               NaN             NaN
# 125     W Jaffer  ...       wides         0               NaN             NaN
# 126     W Jaffer  ...         NaN         0               NaN             NaN
# 127     W Jaffer  ...         NaN         0               NaN             NaN
# 128     R Dravid  ...         NaN         0               NaN             NaN
# ...          ...  ...         ...       ...               ...             ...
# 196792   SS Iyer  ...         NaN         0               NaN             NaN
# 196793   VR Iyer  ...         NaN         0               NaN             NaN
# 196794   VR Iyer  ...         NaN         0               NaN             NaN
# 196795   SS Iyer  ...         NaN         0               NaN             NaN
# 196796   VR Iyer  ...         NaN         0               NaN             NaN
#
#         fielder current_score  runs_left balls_left wickets_left        crr
# 124         NaN             1        221        119           10   6.000000
# 125         NaN             2        220        118           10   6.000000
# 126         NaN             2        220        117           10   4.000000
# 127         NaN             3        219        116           10   4.500000
# 128         NaN             4        218        115           10   4.800000
# ...         ...           ...        ...        ...          ...        ...
# 196792      NaN           110          3         61            8  11.186441
# 196793      NaN           111          2         60            8  11.100000
# 196794      NaN           112          1         59            8  11.016393
# 196795      NaN           113          0         58            8  10.935484
# 196796      NaN           114         -1         57            8  10.857143
#
# [94803 rows x 25 columns]

# %%
delivery_df[['current_score', 'over', 'ball', 'crr']].head()
# Out:
#      current_score  over  ball  crr
# 124              1     0     1  6.0
# 125              2     0     2  6.0
# 126              2     0     3  4.0
# 127              3     0     4  4.5
# 128              4     0     5  4.8

# %%
#rrr = remaining runs / remaining overs
delivery_df['rrr'] = delivery_df['runs_left'] * 6 / delivery_df['balls_left']
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_16888\2347359072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr'] = delivery_df['runs_left'] * 6 / delivery_df['balls_left']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... is_wicket player_dismissed  dismissal_kind  fielder  \
# 124     R Dravid  ...         0              NaN             NaN      NaN
# 125     W Jaffer  ...         0              NaN             NaN      NaN
# 126     W Jaffer  ...         0              NaN             NaN      NaN
# 127     W Jaffer  ...         0              NaN             NaN      NaN
# 128     R Dravid  ...         0              NaN             NaN      NaN
# ...          ...  ...       ...              ...             ...      ...
# 196792   SS Iyer  ...         0              NaN             NaN      NaN
# 196793   VR Iyer  ...         0              NaN             NaN      NaN
# 196794   VR Iyer  ...         0              NaN             NaN      NaN
# 196795   SS Iyer  ...         0              NaN             NaN      NaN
# 196796   VR Iyer  ...         0              NaN             NaN      NaN
#
#         current_score runs_left  balls_left wickets_left        crr        rrr
# 124                 1       221         119           10   6.000000  11.142857
# 125                 2       220         118           10   6.000000  11.186441
# 126                 2       220         117           10   4.000000  11.282051
# 127                 3       219         116           10   4.500000  11.327586
# 128                 4       218         115           10   4.800000  11.373913
# ...               ...       ...         ...          ...        ...        ...
# 196792            110         3          61            8  11.186441   0.295082
# 196793            111         2          60            8  11.100000   0.200000
# 196794            112         1          59            8  11.016393   0.101695
# 196795            113         0          58            8  10.935484   0.000000
# 196796            114        -1          57            8  10.857143  -0.105263
#
# [94803 rows x 26 columns]

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result, axis=1)
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_16888\343102418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['result'] = delivery_df.apply(result, axis=1)

# %%
delivery_df.to_csv('delivery_df.csv', index=False)
print(delivery_df.shape)
delivery_df.head()
delivery_df
# Out:
# (94803, 27)
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 196792   1426312    Chennai  Kolkata Knight Riders           113       2
# 196793   1426312    Chennai  Kolkata Knight Riders           113       2
# 196794   1426312    Chennai  Kolkata Knight Riders           113       2
# 196795   1426312    Chennai  Kolkata Knight Riders           113       2
# 196796   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... player_dismissed dismissal_kind  fielder  current_score  \
# 124     R Dravid  ...              NaN            NaN      NaN              1
# 125     W Jaffer  ...              NaN            NaN      NaN              2
# 126     W Jaffer  ...              NaN            NaN      NaN              2
# 127     W Jaffer  ...              NaN            NaN      NaN              3
# 128     R Dravid  ...              NaN            NaN      NaN              4
# ...          ...  ...              ...            ...      ...            ...
# 196792   SS Iyer  ...              NaN            NaN      NaN            110
# 196793   VR Iyer  ...              NaN            NaN      NaN            111
# 196794   VR Iyer  ...              NaN            NaN      NaN            112
# 196795   SS Iyer  ...              NaN            NaN      NaN            113
# 196796   VR Iyer  ...              NaN            NaN      NaN            114
#
#         runs_left balls_left  wickets_left        crr        rrr result
# 124           221        119            10   6.000000  11.142857      0
# 125           220        118            10   6.000000  11.186441      0
# 126           220        117            10   4.000000  11.282051      0
# 127           219        116            10   4.500000  11.327586      0
# 128           218        115            10   4.800000  11.373913      0
# ...           ...        ...           ...        ...        ...    ...
# 196792          3         61             8  11.186441   0.295082      1
# 196793          2         60             8  11.100000   0.200000      1
# 196794          1         59             8  11.016393   0.101695      1
# 196795          0         58             8  10.935484   0.000000      1
# 196796         -1         57             8  10.857143  -0.105263      1
#
# [94803 rows x 27 columns]

# %%
final_df = delivery_df[['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left', 'wickets_left', 'total_runs_x', 'crr', 'rrr', 'result']]

# %%
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 196792        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 196793        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 196794        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 196795        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 196796        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 124           221         119            10           222   6.000000
# 125           220         118            10           222   6.000000
# 126           220         117            10           222   4.000000
# 127           219         116            10           222   4.500000
# 128           218         115            10           222   4.800000
# ...           ...         ...           ...           ...        ...
# 196792          3          61             8           113  11.186441
# 196793          2          60             8           113  11.100000
# 196794          1          59             8           113  11.016393
# 196795          0          58             8           113  10.935484
# 196796         -1          57             8           113  10.857143
#
#               rrr  result
# 124     11.142857       0
# 125     11.186441       0
# 126     11.282051       0
# 127     11.327586       0
# 128     11.373913       0
# ...           ...     ...
# 196792   0.295082       1
# 196793   0.200000       1
# 196794   0.101695       1
# 196795   0.000000       1
# 196796  -0.105263       1
#
# [94803 rows x 10 columns]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#                        batting_team                 bowling_team        city  \
# 193748                 Punjab Kings          Chennai Super Kings  Dharamsala
# 185878          Chennai Super Kings  Royal Challengers Bengaluru     Chennai
# 142     Royal Challengers Bangalore        Kolkata Knight Riders   Bangalore
# 62511                Mumbai Indians              Kings XI Punjab  Dharamsala
# 148989               Delhi Capitals               Mumbai Indians         NaN
# ...                             ...                          ...         ...
# 113447        Kolkata Knight Riders  Royal Challengers Bangalore   Bengaluru
# 31407                Mumbai Indians  Royal Challengers Bangalore   Bangalore
# 80258              Rajasthan Royals               Mumbai Indians   Ahmedabad
# 113667             Delhi Daredevils          Chennai Super Kings        Pune
# 114363        Kolkata Knight Riders          Chennai Super Kings     Kolkata
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 193748         51          17             2           167  6.757282
# 185878         23          19             6           173  8.910891
# 142           211         102             8           222  3.666667
# 62511          50           5             1           183  6.939130
# 148989         58          -1             2           200  7.041322
# ...           ...         ...           ...           ...       ...
# 113447         23          16             6           175  8.769231
# 31407          96          80             9           140  6.600000
# 80258         112          74             9           164  6.782609
# 113667         96          38             6           211  8.414634
# 114363         36          30             6           177  9.400000
#
#                rrr  result
# 193748   18.000000       0
# 185878    7.263158       1
# 142      12.411765       0
# 62511    60.000000       0
# 148989 -348.000000       0
# ...            ...     ...
# 113447    8.625000       1
# 31407     7.200000       1
# 80258     9.081081       1
# 113667   15.157895       0
# 114363    7.200000       1
#
# [94803 rows x 10 columns]

# %%
final_df.sample()
# Out:
#           batting_team      bowling_team    city  runs_left  balls_left  \
# 39318  Kings XI Punjab  Rajasthan Royals  Jaipur        123          65
#
#        wickets_left  total_runs_x       crr        rrr  result
# 39318             6           191  7.418182  11.353846       0

# %%
final_df.isnull().sum()
final_df
# Out:
#                        batting_team                 bowling_team        city  \
# 193748                 Punjab Kings          Chennai Super Kings  Dharamsala
# 185878          Chennai Super Kings  Royal Challengers Bengaluru     Chennai
# 142     Royal Challengers Bangalore        Kolkata Knight Riders   Bangalore
# 62511                Mumbai Indians              Kings XI Punjab  Dharamsala
# 148989               Delhi Capitals               Mumbai Indians         NaN
# ...                             ...                          ...         ...
# 113447        Kolkata Knight Riders  Royal Challengers Bangalore   Bengaluru
# 31407                Mumbai Indians  Royal Challengers Bangalore   Bangalore
# 80258              Rajasthan Royals               Mumbai Indians   Ahmedabad
# 113667             Delhi Daredevils          Chennai Super Kings        Pune
# 114363        Kolkata Knight Riders          Chennai Super Kings     Kolkata
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 193748         51          17             2           167  6.757282
# 185878         23          19             6           173  8.910891
# 142           211         102             8           222  3.666667
# 62511          50           5             1           183  6.939130
# 148989         58          -1             2           200  7.041322
# ...           ...         ...           ...           ...       ...
# 113447         23          16             6           175  8.769231
# 31407          96          80             9           140  6.600000
# 80258         112          74             9           164  6.782609
# 113667         96          38             6           211  8.414634
# 114363         36          30             6           177  9.400000
#
#                rrr  result
# 193748   18.000000       0
# 185878    7.263158       1
# 142      12.411765       0
# 62511    60.000000       0
# 148989 -348.000000       0
# ...            ...     ...
# 113447    8.625000       1
# 31407     7.200000       1
# 80258     9.081081       1
# 113667   15.157895       0
# 114363    7.200000       1
#
# [94803 rows x 10 columns]

# %%
final_df.dropna(inplace=True)
final_df
# Out:
#                        batting_team                 bowling_team        city  \
# 193748                 Punjab Kings          Chennai Super Kings  Dharamsala
# 185878          Chennai Super Kings  Royal Challengers Bengaluru     Chennai
# 142     Royal Challengers Bangalore        Kolkata Knight Riders   Bangalore
# 62511                Mumbai Indians              Kings XI Punjab  Dharamsala
# 43643           Chennai Super Kings              Kings XI Punjab     Chennai
# ...                             ...                          ...         ...
# 113447        Kolkata Knight Riders  Royal Challengers Bangalore   Bengaluru
# 31407                Mumbai Indians  Royal Challengers Bangalore   Bangalore
# 80258              Rajasthan Royals               Mumbai Indians   Ahmedabad
# 113667             Delhi Daredevils          Chennai Super Kings        Pune
# 114363        Kolkata Knight Riders          Chennai Super Kings     Kolkata
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 193748         51          17             2           167  6.757282
# 185878         23          19             6           173  8.910891
# 142           211         102             8           222  3.666667
# 62511          50           5             1           183  6.939130
# 43643          99          77             9           156  7.953488
# ...           ...         ...           ...           ...       ...
# 113447         23          16             6           175  8.769231
# 31407          96          80             9           140  6.600000
# 80258         112          74             9           164  6.782609
# 113667         96          38             6           211  8.414634
# 114363         36          30             6           177  9.400000
#
#               rrr  result
# 193748  18.000000       0
# 185878   7.263158       1
# 142     12.411765       0
# 62511   60.000000       0
# 43643    7.714286       0
# ...           ...     ...
# 113447   8.625000       1
# 31407    7.200000       1
# 80258    9.081081       1
# 113667  15.157895       0
# 114363   7.200000       1
#
# [88782 rows x 10 columns]

# %%
final_df = final_df[final_df['balls_left'] != 0]
final_df
# Out:
#                        batting_team                 bowling_team        city  \
# 193748                 Punjab Kings          Chennai Super Kings  Dharamsala
# 185878          Chennai Super Kings  Royal Challengers Bengaluru     Chennai
# 142     Royal Challengers Bangalore        Kolkata Knight Riders   Bangalore
# 62511                Mumbai Indians              Kings XI Punjab  Dharamsala
# 43643           Chennai Super Kings              Kings XI Punjab     Chennai
# ...                             ...                          ...         ...
# 113447        Kolkata Knight Riders  Royal Challengers Bangalore   Bengaluru
# 31407                Mumbai Indians  Royal Challengers Bangalore   Bangalore
# 80258              Rajasthan Royals               Mumbai Indians   Ahmedabad
# 113667             Delhi Daredevils          Chennai Super Kings        Pune
# 114363        Kolkata Knight Riders          Chennai Super Kings     Kolkata
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 193748         51          17             2           167  6.757282
# 185878         23          19             6           173  8.910891
# 142           211         102             8           222  3.666667
# 62511          50           5             1           183  6.939130
# 43643          99          77             9           156  7.953488
# ...           ...         ...           ...           ...       ...
# 113447         23          16             6           175  8.769231
# 31407          96          80             9           140  6.600000
# 80258         112          74             9           164  6.782609
# 113667         96          38             6           211  8.414634
# 114363         36          30             6           177  9.400000
#
#               rrr  result
# 193748  18.000000       0
# 185878   7.263158       1
# 142     12.411765       0
# 62511   60.000000       0
# 43643    7.714286       0
# ...           ...     ...
# 113447   8.625000       1
# 31407    7.200000       1
# 80258    9.081081       1
# 113667  15.157895       0
# 114363   7.200000       1
#
# [88496 rows x 10 columns]

# %%
final_df.to_csv('final_df.csv', index=False)
print(final_df.shape)
final_df.head()
# Out:
# (88496, 10)
#                        batting_team                 bowling_team        city  \
# 193748                 Punjab Kings          Chennai Super Kings  Dharamsala
# 185878          Chennai Super Kings  Royal Challengers Bengaluru     Chennai
# 142     Royal Challengers Bangalore        Kolkata Knight Riders   Bangalore
# 62511                Mumbai Indians              Kings XI Punjab  Dharamsala
# 43643           Chennai Super Kings              Kings XI Punjab     Chennai
#
#         runs_left  balls_left  wickets_left  total_runs_x       crr  \
# 193748         51          17             2           167  6.757282
# 185878         23          19             6           173  8.910891
# 142           211         102             8           222  3.666667
# 62511          50           5             1           183  6.939130
# 43643          99          77             9           156  7.953488
#
#               rrr  result
# 193748  18.000000       0
# 185878   7.263158       1
# 142     12.411765       0
# 62511   60.000000       0
# 43643    7.714286       0

# %%
X = final_df.iloc[:,:-1]
y = final_df.iloc[:, -1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 1)

# %%
X_train
# Out:
#                  batting_team                 bowling_team            city  \
# 111704       Delhi Daredevils              Kings XI Punjab           Delhi
# 47540          Mumbai Indians        Kolkata Knight Riders          Mumbai
# 191696    Sunrisers Hyderabad  Royal Challengers Bengaluru       Hyderabad
# 160306    Chennai Super Kings          Sunrisers Hyderabad         Sharjah
# 113676       Delhi Daredevils          Chennai Super Kings            Pune
# ...                       ...                          ...             ...
# 14527         Kings XI Punjab        Kolkata Knight Riders  Port Elizabeth
# 28590     Chennai Super Kings        Kolkata Knight Riders         Chennai
# 96946        Delhi Daredevils          Sunrisers Hyderabad       Hyderabad
# 179795       Rajasthan Royals  Royal Challengers Bangalore       Bengaluru
# 150938  Kolkata Knight Riders               Mumbai Indians         Chennai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 111704         69          51             6           143   6.434783
# 47540          78          50             8           140   5.314286
# 191696        169          95             8           206   8.880000
# 160306         25          24             6           134   6.812500
# 113676         82          29             6           211   8.505495
# ...           ...         ...           ...           ...        ...
# 14527          81          70             8           153   8.640000
# 28590          58          74             9           139  10.565217
# 96946          78          73             9           146   8.680851
# 179795         64          29             7           189   8.241758
# 150938         23          19             5           152   7.663366
#
#               rrr
# 111704   8.117647
# 47540    9.360000
# 191696  10.673684
# 160306   6.250000
# 113676  16.965517
# ...           ...
# 14527    6.942857
# 28590    4.702703
# 96946    6.410959
# 179795  13.241379
# 150938   7.263158
#
# [70796 rows x 9 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
]
,remainder= 'passthrough')

# %% [markdown]
# **LogisticRegression** **Model**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
lr_pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', LogisticRegression(solver= 'liblinear'))
])

# %%
lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
X_train
# Out:
#                  batting_team                 bowling_team            city  \
# 111704       Delhi Daredevils              Kings XI Punjab           Delhi
# 47540          Mumbai Indians        Kolkata Knight Riders          Mumbai
# 191696    Sunrisers Hyderabad  Royal Challengers Bengaluru       Hyderabad
# 160306    Chennai Super Kings          Sunrisers Hyderabad         Sharjah
# 113676       Delhi Daredevils          Chennai Super Kings            Pune
# ...                       ...                          ...             ...
# 14527         Kings XI Punjab        Kolkata Knight Riders  Port Elizabeth
# 28590     Chennai Super Kings        Kolkata Knight Riders         Chennai
# 96946        Delhi Daredevils          Sunrisers Hyderabad       Hyderabad
# 179795       Rajasthan Royals  Royal Challengers Bangalore       Bengaluru
# 150938  Kolkata Knight Riders               Mumbai Indians         Chennai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# 111704         69          51             6           143   6.434783
# 47540          78          50             8           140   5.314286
# 191696        169          95             8           206   8.880000
# 160306         25          24             6           134   6.812500
# 113676         82          29             6           211   8.505495
# ...           ...         ...           ...           ...        ...
# 14527          81          70             8           153   8.640000
# 28590          58          74             9           139  10.565217
# 96946          78          73             9           146   8.680851
# 179795         64          29             7           189   8.241758
# 150938         23          19             5           152   7.663366
#
#               rrr
# 111704   8.117647
# 47540    9.360000
# 191696  10.673684
# 160306   6.250000
# 113676  16.965517
# ...           ...
# 14527    6.942857
# 28590    4.702703
# 96946    6.410959
# 179795  13.241379
# 150938   7.263158
#
# [70796 rows x 9 columns]

# %%
y_pred = lr_pipe.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0], shape=(17700,))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8761016949152542

# %%
lr_pipe.predict_proba(X_test)[577]*100
# Out:
# array([36.79566464, 63.20433536])

# %% [markdown]
# **RandomForest** **Model**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
rf_pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', RandomForestClassifier(random_state=42))
])

# %%
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', RandomForestClassifier(random_state=42))])

# %%
y_pred = rf_pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9987570621468926

# %% [markdown]
# **Make** **Model** **From** **LogisticRegression** **and** **testing**

# %%
def match_progression(x_df, match_id, pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets_left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,829791,lr_pipe)
temp_df
# Out:
# Target- 183
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 88152            1                5                0  52.8  47.2
# 88158            2               10                0  44.3  55.7
# 88164            3               10                0  37.3  62.7
# 88170            4               15                1  36.6  63.4
# 88176            5               11                0  29.3  70.7
# 88183            6                6                0  28.9  71.1
# 88189            7                3                0  32.3  67.7
# 88196            8                6                1  45.2  54.8
# 88202            9                3                1  63.0  37.0
# 88208           10                5                0  63.8  36.2
# 88214           11               10                1  70.4  29.6
# 88221           12                2                0  74.9  25.1
# 88227           13               16                0  61.3  38.7
# 88233           14               20                0  39.6  60.4
# 88240           15               14                1  40.8  59.2
# 88246           16               19                0  22.6  77.4
# 88252           17                5                1  35.0  65.0
# 88258           18               11                1  39.4  60.6
# 88264           19                5                0  40.6  59.4

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-183')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bengaluru',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Jaipur', 'Chennai',
#        'Kolkata', 'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Dharamsala', 'Pune', 'Hyderabad', 'Raipur', 'Ranchi',
#        'Abu Dhabi', nan, 'Cuttack', 'Visakhapatnam', 'Bengaluru',
#        'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai', 'Guwahati', 'Mohali'],
#       dtype=object)

# %%
import pickle
pickle.dump(lr_pipe, open('lr_pipe.pkl', 'wb'))
